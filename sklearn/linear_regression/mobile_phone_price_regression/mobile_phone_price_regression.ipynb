# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import root_mean_squared_error, r2_score

# %%
df = pd.read_csv('data/mobile_phone_price_regression.csv', index_col=0)
df
# Out:
#                                       Name  Rating  Spec_score  \
# 0                    Samsung Galaxy F14 5G    4.65          68
# 1                       Samsung Galaxy A11    4.20          63
# 2                       Samsung Galaxy A13    4.30          75
# 3                       Samsung Galaxy F23    4.10          73
# 4     Samsung Galaxy A03s (4GB RAM + 64GB)    4.10          69
# ...                                    ...     ...         ...
# 1365                               TCL 40R    4.05          75
# 1366                 TCL 50 XL NxtPaper 5G    4.10          80
# 1367                 TCL 50 XE NxtPaper 5G    4.00          80
# 1368                    TCL 40 NxtPaper 5G    4.50          79
# 1369                           TCL Trifold    4.65          93
#
#                                 No_of_sim        Ram            Battery  \
# 0           Dual Sim, 3G, 4G, 5G, VoLTE,    4 GB RAM  6000 mAh Battery
# 1               Dual Sim, 3G, 4G, VoLTE,    2 GB RAM  4000 mAh Battery
# 2               Dual Sim, 3G, 4G, VoLTE,    4 GB RAM  5000 mAh Battery
# 3               Dual Sim, 3G, 4G, VoLTE,    4 GB RAM   6000 mAh Battery
# 4               Dual Sim, 3G, 4G, VoLTE,    4 GB RAM  5000 mAh Battery
# ...                                   ...        ...                ...
# 1365        Dual Sim, 3G, 4G, 5G, VoLTE,    4 GB RAM  5000 mAh Battery
# 1366            Dual Sim, 3G, 4G, VoLTE,    8 GB RAM  5000 mAh Battery
# 1367        Dual Sim, 3G, 4G, 5G, VoLTE,    6 GB RAM  5000 mAh Battery
# 1368        Dual Sim, 3G, 4G, 5G, VoLTE,    6 GB RAM  5000 mAh Battery
# 1369  Dual Sim, 3G, 4G, 5G, VoLTE, Vo5G,   12 GB RAM  4600 mAh Battery
#
#          Display                                             Camera  \
# 0     6.6 inches    50 MP + 2 MP Dual Rear &amp; 13 MP Front Camera
# 1     6.4 inches  13 MP + 5 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 2     6.6 inches            50 MP Quad Rear &amp; 8 MP Front Camera
# 3     6.4 inches           48 MP Quad Rear &amp; 13 MP Front Camera
# 4     6.5 inches  13 MP + 2 MP + 2 MP Triple Rear &amp; 5 MP Fro...
# ...          ...                                                ...
# 1365  6.6 inches  50 MP + 2 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 1366  6.8 inches    50 MP + 2 MP Dual Rear &amp; 16 MP Front Camera
# 1367  6.6 inches    50 MP + 2 MP Dual Rear &amp; 16 MP Front Camera
# 1368  6.6 inches  50 MP + 2 MP + 2 MP Triple Rear &amp; 8 MP Fro...
# 1369   10 inches                     Foldable Display, Dual Display
#
#                                         External_Memory Android_version  \
# 0                      Memory Card Supported, upto 1 TB              13
# 1                    Memory Card Supported, upto 512 GB              10
# 2                      Memory Card Supported, upto 1 TB              12
# 3                      Memory Card Supported, upto 1 TB              12
# 4                      Memory Card Supported, upto 1 TB              11
# ...                                                 ...             ...
# 1365                               Memory Card (Hybrid)              12
# 1366                               Memory Card (Hybrid)              14
# 1367                   Memory Card Supported, upto 1 TB              13
# 1368                   Memory Card Supported, upto 1 TB              13
# 1369  50 MP + 48 MP + 8 MP Triple Rear &amp; 32 MP F...              13
#
#          Price  company   Inbuilt_memory       fast_charging  \
# 0        9,999  Samsung   128 GB inbuilt   25W Fast Charging
# 1        9,990  Samsung    32 GB inbuilt   15W Fast Charging
# 2       11,999  Samsung    64 GB inbuilt   25W Fast Charging
# 3       11,999  Samsung    64 GB inbuilt                 NaN
# 4       11,999  Samsung    64 GB inbuilt   15W Fast Charging
# ...        ...      ...              ...                 ...
# 1365    18,999      TCL    64 GB inbuilt   15W Fast Charging
# 1366    24,990      TCL   128 GB inbuilt   33W Fast Charging
# 1367    23,990      TCL   256 GB inbuilt   18W Fast Charging
# 1368    22,499      TCL   256 GB inbuilt   15W Fast Charging
# 1369  1,19,990      TCL   256 GB inbuilt   67W Fast Charging
#
#                                   Screen_resolution             Processor  \
# 0      2408 x 1080 px Display with Water Drop Notch   Octa Core Processor
# 1             720 x 1560 px Display with Punch Hole     1.8 GHz Processor
# 2      1080 x 2408 px Display with Water Drop Notch       2 GHz Processor
# 3                                     720 x 1600 px             Octa Core
# 4       720 x 1600 px Display with Water Drop Notch             Octa Core
# ...                                             ...                   ...
# 1365                                  720 x 1612 px             Octa Core
# 1366                                 1200 x 2400 px             Octa Core
# 1367                                  720 x 1612 px             Octa Core
# 1368                                  720 x 1612 px             Octa Core
# 1369                                 1916 x 2160 px             Octa Core
#
#          Processor_name
# 0           Exynos 1330
# 1             Octa Core
# 2             Octa Core
# 3             Helio G88
# 4             Helio P35
# ...                 ...
# 1365   Dimensity 700 5G
# 1366     Dimensity 7050
# 1367     Dimensity 6080
# 1368     Dimensity 6020
# 1369  Snapdragon 8 Gen2
#
# [1370 rows x 17 columns]

# %%
df = df[['Rating', 'Spec_score', 'Ram', 'Battery', 'Display', 'Android_version', 'Price', 'Inbuilt_memory']]
df
# Out:
#       Rating  Spec_score        Ram            Battery     Display  \
# 0       4.65          68   4 GB RAM  6000 mAh Battery   6.6 inches
# 1       4.20          63   2 GB RAM  4000 mAh Battery   6.4 inches
# 2       4.30          75   4 GB RAM  5000 mAh Battery   6.6 inches
# 3       4.10          73   4 GB RAM   6000 mAh Battery  6.4 inches
# 4       4.10          69   4 GB RAM  5000 mAh Battery   6.5 inches
# ...      ...         ...        ...                ...         ...
# 1365    4.05          75   4 GB RAM  5000 mAh Battery   6.6 inches
# 1366    4.10          80   8 GB RAM  5000 mAh Battery   6.8 inches
# 1367    4.00          80   6 GB RAM  5000 mAh Battery   6.6 inches
# 1368    4.50          79   6 GB RAM  5000 mAh Battery   6.6 inches
# 1369    4.65          93  12 GB RAM  4600 mAh Battery    10 inches
#
#      Android_version     Price   Inbuilt_memory
# 0                 13     9,999   128 GB inbuilt
# 1                 10     9,990    32 GB inbuilt
# 2                 12    11,999    64 GB inbuilt
# 3                 12    11,999    64 GB inbuilt
# 4                 11    11,999    64 GB inbuilt
# ...              ...       ...              ...
# 1365              12    18,999    64 GB inbuilt
# 1366              14    24,990   128 GB inbuilt
# 1367              13    23,990   256 GB inbuilt
# 1368              13    22,499   256 GB inbuilt
# 1369              13  1,19,990   256 GB inbuilt
#
# [1370 rows x 8 columns]

# %%
def process_data(df):
    def process_rating(v):
        return float(v)

    def process_spec_score(v):
        return int(v)

    def process_ram(v):
        try: return float(v.upper().split(' GB')[0])
        except: return 0

    def process_battery(v):
        try: return float(v.upper().split(' MAH')[0])
        except: return 0

    def process_display(v):
        try: return float(v.split(' ')[0])
        except: return 0

    def process_android_version(v):
        try: return float(v.split(' ')[0].split('.')[0])
        except: return 0

    def process_price(v):
        try: return int(v.replace(',', ''))
        except: return 0

    def process_inbuilt_memory(v):
        try: return float(v.upper().split(' GB')[0].split(' TB')[0])
        except: return 0


    df.loc[:, 'Rating'] = df['Rating'].apply(process_rating)
    df.loc[:, 'Spec_score'] = df['Spec_score'].apply(process_spec_score)
    df.loc[:, 'Ram'] = df['Ram'].apply(process_ram)
    df.loc[:, 'Battery'] = df['Battery'].apply(process_battery)
    df.loc[:, 'Display'] = df['Display'].apply(process_display)
    df.loc[:, 'Android_version'] = df['Android_version'].apply(process_android_version)
    df.loc[:, 'Price'] = df['Price'].apply(process_price)
    df.loc[:, 'Inbuilt_memory'] = df['Inbuilt_memory'].apply(process_inbuilt_memory)
    return df

# %%
processed_df = process_data(df)
processed_df
# Out:
#       Rating  Spec_score   Ram Battery Display Android_version   Price  \
# 0       4.65          68   4.0  6000.0     6.6            13.0    9999
# 1       4.20          63   2.0  4000.0     6.4            10.0    9990
# 2       4.30          75   4.0  5000.0     6.6            12.0   11999
# 3       4.10          73   4.0  6000.0     6.4            12.0   11999
# 4       4.10          69   4.0  5000.0     6.5            11.0   11999
# ...      ...         ...   ...     ...     ...             ...     ...
# 1365    4.05          75   4.0  5000.0     6.6            12.0   18999
# 1366    4.10          80   8.0  5000.0     6.8            14.0   24990
# 1367    4.00          80   6.0  5000.0     6.6            13.0   23990
# 1368    4.50          79   6.0  5000.0     6.6            13.0   22499
# 1369    4.65          93  12.0  4600.0    10.0            13.0  119990
#
#      Inbuilt_memory
# 0             128.0
# 1              32.0
# 2              64.0
# 3              64.0
# 4              64.0
# ...             ...
# 1365           64.0
# 1366          128.0
# 1367          256.0
# 1368          256.0
# 1369          256.0
#
# [1370 rows x 8 columns]

# %%
X = np.array(df[['Rating', 'Spec_score', 'Ram', 'Battery', 'Display', 'Android_version', 'Inbuilt_memory']])
X.shape
# Out:
# (1370, 7)

# %%
y = np.array(df[['Price']])
y.shape
# Out:
# (1370, 1)

# %%
linear_regression_model = LinearRegression()
linear_regression_model
# Out:
# LinearRegression()

# %%
linear_regression_model.fit(X, y)
# Out:
# LinearRegression()

# %%
coef_result = linear_regression_model.coef_
coef_result
# Out:
# array([[-3570.83828676,  1651.62415927,   110.29424838,    -8.63131149,
#           -10.14175835,  -318.18731867,    77.73127691]])

# %%
intercept_result = linear_regression_model.intercept_
intercept_result
# Out:
# array([-52519.96910331])

# %%
y_pred = linear_regression_model.predict(X)
y_pred
# Out:
# array([[-2414.38357008],
#        [ 1470.79507494],
#        [14371.47603404],
#        ...,
#        [38527.65466074],
#        [35090.61135809],
#        [61757.53195364]])

# %%
root_mean_squared_error(y, y_pred)
# Out:
# 21539.38198345468

# %%
r2_score(y, y_pred)
# Out:
# 0.49933170907427327
