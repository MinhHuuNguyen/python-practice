# %%
import re
from glob import glob

import pandas as pd
from nltk.corpus import stopwords
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
file_paths = glob('data/20_newsgroups_dataset/**/*')
len(file_paths)
# Out:
# 18828

# %%
data_list, label_list = [], []
for path in file_paths:
    try:
        with open(path, 'r') as file:
            data = file.readlines()
            data = ''.join(data)
            data_list.append(data)
            label = path.split('/')[-2]
            label_list.append(label)
    except:
        print(path)
# Out:
# data/20_newsgroups_dataset/rec.autos/103700
# data/20_newsgroups_dataset/rec.autos/103725
# data/20_newsgroups_dataset/rec.autos/103694
# data/20_newsgroups_dataset/rec.autos/101596
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51892
# data/20_newsgroups_dataset/comp.sys.mac.hardware/52165
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51941
# data/20_newsgroups_dataset/comp.sys.mac.hardware/52196
# data/20_newsgroups_dataset/comp.sys.mac.hardware/52164
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51593
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51594
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51592
# data/20_newsgroups_dataset/comp.sys.mac.hardware/52033
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51865
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51916
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51917
# data/20_newsgroups_dataset/comp.sys.mac.hardware/50467
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51904
# data/20_newsgroups_dataset/comp.sys.mac.hardware/51591
# data/20_newsgroups_dataset/alt.atheism/49960
# data/20_newsgroups_dataset/alt.atheism/52910
# data/20_newsgroups_dataset/alt.atheism/51060
# data/20_newsgroups_dataset/alt.atheism/52909
# data/20_newsgroups_dataset/alt.atheism/52499
# data/20_newsgroups_dataset/alt.atheism/54164
# data/20_newsgroups_dataset/alt.atheism/54163
# data/20_newsgroups_dataset/rec.sport.baseball/104562
# data/20_newsgroups_dataset/rec.sport.baseball/104474
# data/20_newsgroups_dataset/rec.sport.baseball/104419
# data/20_newsgroups_dataset/rec.sport.baseball/104572
# data/20_newsgroups_dataset/rec.sport.baseball/104984
# data/20_newsgroups_dataset/rec.sport.baseball/104352
# data/20_newsgroups_dataset/rec.sport.baseball/104471
# data/20_newsgroups_dataset/rec.sport.hockey/54516
# data/20_newsgroups_dataset/rec.sport.hockey/54036
# data/20_newsgroups_dataset/rec.sport.hockey/54000
# data/20_newsgroups_dataset/rec.sport.hockey/53879
# data/20_newsgroups_dataset/rec.sport.hockey/54042
# data/20_newsgroups_dataset/rec.sport.hockey/54769
# data/20_newsgroups_dataset/sci.crypt/15672
# data/20_newsgroups_dataset/sci.med/59239
# data/20_newsgroups_dataset/sci.med/59055
# data/20_newsgroups_dataset/sci.med/59535
# data/20_newsgroups_dataset/comp.windows.x/67305
# data/20_newsgroups_dataset/comp.windows.x/66871
# data/20_newsgroups_dataset/comp.windows.x/68001
# data/20_newsgroups_dataset/comp.windows.x/66923
# data/20_newsgroups_dataset/comp.graphics/38291
# data/20_newsgroups_dataset/comp.graphics/38757
# data/20_newsgroups_dataset/comp.graphics/38489
# data/20_newsgroups_dataset/comp.graphics/38490
# data/20_newsgroups_dataset/comp.graphics/38568
# data/20_newsgroups_dataset/comp.sys.ibm.pc.hardware/60868
# data/20_newsgroups_dataset/comp.sys.ibm.pc.hardware/60498
# data/20_newsgroups_dataset/comp.sys.ibm.pc.hardware/61116
# data/20_newsgroups_dataset/comp.sys.ibm.pc.hardware/60936
# data/20_newsgroups_dataset/comp.sys.ibm.pc.hardware/60366
# data/20_newsgroups_dataset/sci.electronics/53883
# data/20_newsgroups_dataset/sci.electronics/54070
# data/20_newsgroups_dataset/sci.electronics/54485
# data/20_newsgroups_dataset/sci.electronics/54071
# data/20_newsgroups_dataset/sci.electronics/53721
# data/20_newsgroups_dataset/sci.electronics/53803
# data/20_newsgroups_dataset/sci.space/61293
# data/20_newsgroups_dataset/sci.space/61534
# data/20_newsgroups_dataset/sci.space/61556
# data/20_newsgroups_dataset/misc.forsale/76112
# data/20_newsgroups_dataset/misc.forsale/76548
# data/20_newsgroups_dataset/misc.forsale/76843
# data/20_newsgroups_dataset/talk.religion.misc/83777
# data/20_newsgroups_dataset/talk.religion.misc/83651
# data/20_newsgroups_dataset/talk.religion.misc/82776

# %%
len(data_list), len(label_list)
# Out:
# (18756, 18756)

# %%
df = pd.DataFrame(data={
    'data': data_list,
    'label': label_list
})
df
# Out:
#                                                     data  \
# 0      From: hm@cs.brown.edu (Harry Mamaysky)\nSubjec...
# 1      From: waldo@cybernet.cse.fau.edu (Todd J. Dick...
# 2      From: C.L.Gannon@newcastle.ac.uk (Space Cadet)...
# 3      From: shaig@Think.COM (Shai Guday)\nSubject: B...
# 4      From: ez000281@hamlet.ucdavis.edu ()\nSubject:...
# ...                                                  ...
# 18751  From: porta@wam.umd.edu (David Palmer)\nSubjec...
# 18752  From: decay@cbnewsj.cb.att.com (dean.kaflowitz...
# 18753  From: ekr@kyle.eitech.com (Eric Rescorla)\nSub...
# 18754  From: "David R. Sacco" <dsav+@andrew.cmu.edu>\...
# 18755  Subject: Re: "Imaginary" Friends - Info and Ex...
#
#                        label
# 0      talk.politics.mideast
# 1      talk.politics.mideast
# 2      talk.politics.mideast
# 3      talk.politics.mideast
# 4      talk.politics.mideast
# ...                      ...
# 18751     talk.religion.misc
# 18752     talk.religion.misc
# 18753     talk.religion.misc
# 18754     talk.religion.misc
# 18755     talk.religion.misc
#
# [18756 rows x 2 columns]

# %%
def decontact(phrase):
    # specific
    phrase = re.sub(r"won't", "will not", phrase)
    phrase = re.sub(r"can\'t", "can not", phrase)

    # general
    phrase = re.sub(r"n\'t", " not", phrase)
    phrase = re.sub(r"\'re", " are", phrase)
    phrase = re.sub(r"\'s", " is", phrase)
    phrase = re.sub(r"\'d", " would", phrase)
    phrase = re.sub(r"\'ll", " will", phrase)
    phrase = re.sub(r"\'t", " not", phrase)
    phrase = re.sub(r"\'ve", " have", phrase)
    phrase = re.sub(r"\'m", " am", phrase)
    return phrase

# %%
def process_string(stringg):
    stringg = decontact(stringg)

    # REPLACING NEW LINES BY 'WHITE SPACE'
    stringg = re.sub(r'\n', " ", stringg)
    # REPLACING NUMBERS
    stringg = re.sub(r'\d+(\.\d+)?', 'numbers', stringg)
    # REPLACING EMAIL IDs BY 'MAILID'
    stringg = re.sub(r'^.+@[^\.].*\.[a-z]{2,}$','MailID', stringg)
    # REPLACING URLs  BY 'Links'
    stringg = re.sub(r'^http\://[a-zA-Z0-9\-\.]+\.[a-zA-Z]{2,3}(/\S*)?$','Links', stringg)
    # REPLACING CURRENCY SIGNS BY 'MONEY'
    stringg = re.sub(r'£|\$', 'Money', stringg)
    # REPLACING LARGE WHITE SPACE BY SINGLE WHITE SPACE
    stringg = re.sub(r'\s+', ' ', stringg)
    # REPLACING LEADING AND TRAILING WHITE SPACE BY SINGLE WHITE SPACE
    stringg = re.sub(r'^\s+|\s+?$', '', stringg)
    # REPLACING CONTACT NUMBERS
    stringg = re.sub(r'^\(?[\d]{3}\)?[\s-]?[\d]{3}[\s-]?[\d]{4}$','contact number', stringg)
    # REPLACING SPECIAL CHARACTERS  BY WHITE SPACE 
    stringg = re.sub(r"[^a-zA-Z0-9]+", " ", stringg)

    return stringg

# %%
df['data'] = df['data'].apply(process_string)
df
# Out:
#                                                     data  \
# 0      From hm cs brown edu Harry Mamaysky Subject He...
# 1      From waldo cybernet cse fau edu Todd J Dicker ...
# 2      From C L Gannon newcastle ac uk Space Cadet Su...
# 3      From shaig Think COM Shai Guday Subject Basil ...
# 4      From eznumbers hamlet ucdavis edu Subject Re T...
# ...                                                  ...
# 18751  From porta wam umd edu David Palmer Subject Re...
# 18752  From decay cbnewsj cb att com dean kaflowitz S...
# 18753  From ekr kyle eitech com Eric Rescorla Subject...
# 18754  From David R Sacco dsav andrew cmu edu Subject...
# 18755  Subject Re Imaginary Friends Info and Experien...
#
#                        label
# 0      talk.politics.mideast
# 1      talk.politics.mideast
# 2      talk.politics.mideast
# 3      talk.politics.mideast
# 4      talk.politics.mideast
# ...                      ...
# 18751     talk.religion.misc
# 18752     talk.religion.misc
# 18753     talk.religion.misc
# 18754     talk.religion.misc
# 18755     talk.religion.misc
#
# [18756 rows x 2 columns]

# %%
# removing stopwords 
stop = stopwords.words('english')
df['clean_data'] = df['data'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
df['length'] = df['clean_data'].apply(len)
df
# Out:
#                                                     data  \
# 0      From hm cs brown edu Harry Mamaysky Subject He...
# 1      From waldo cybernet cse fau edu Todd J Dicker ...
# 2      From C L Gannon newcastle ac uk Space Cadet Su...
# 3      From shaig Think COM Shai Guday Subject Basil ...
# 4      From eznumbers hamlet ucdavis edu Subject Re T...
# ...                                                  ...
# 18751  From porta wam umd edu David Palmer Subject Re...
# 18752  From decay cbnewsj cb att com dean kaflowitz S...
# 18753  From ekr kyle eitech com Eric Rescorla Subject...
# 18754  From David R Sacco dsav andrew cmu edu Subject...
# 18755  Subject Re Imaginary Friends Info and Experien...
#
#                        label  \
# 0      talk.politics.mideast
# 1      talk.politics.mideast
# 2      talk.politics.mideast
# 3      talk.politics.mideast
# 4      talk.politics.mideast
# ...                      ...
# 18751     talk.religion.misc
# 18752     talk.religion.misc
# 18753     talk.religion.misc
# 18754     talk.religion.misc
# 18755     talk.religion.misc
#
#                                               clean_data  length
# 0      From hm cs brown edu Harry Mamaysky Subject He...     948
# 1      From waldo cybernet cse fau edu Todd J Dicker ...     776
# 2      From C L Gannon newcastle ac uk Space Cadet Su...     508
# 3      From shaig Think COM Shai Guday Subject Basil ...    1289
# 4      From eznumbers hamlet ucdavis edu Subject Re T...     862
# ...                                                  ...     ...
# 18751  From porta wam umd edu David Palmer Subject Re...     774
# 18752  From decay cbnewsj cb att com dean kaflowitz S...     981
# 18753  From ekr kyle eitech com Eric Rescorla Subject...    1200
# 18754  From David R Sacco dsav andrew cmu edu Subject...     411
# 18755  Subject Re Imaginary Friends Info Experiences ...     679
#
# [18756 rows x 4 columns]

# %%
label_unique_list = list(df.label.unique())
label_unique_list = sorted(label_unique_list)
label_unique_list
# Out:
# ['alt.atheism',
#  'comp.graphics',
#  'comp.os.ms-windows.misc',
#  'comp.sys.ibm.pc.hardware',
#  'comp.sys.mac.hardware',
#  'comp.windows.x',
#  'misc.forsale',
#  'rec.autos',
#  'rec.motorcycles',
#  'rec.sport.baseball',
#  'rec.sport.hockey',
#  'sci.crypt',
#  'sci.electronics',
#  'sci.med',
#  'sci.space',
#  'soc.religion.christian',
#  'talk.politics.guns',
#  'talk.politics.mideast',
#  'talk.politics.misc',
#  'talk.religion.misc']

# %%
def create_label_idx(label):
    return label_unique_list.index(label)

# %%
df['label_idx'] = df['label'].apply(create_label_idx)
df
# Out:
#                                                     data  \
# 0      From hm cs brown edu Harry Mamaysky Subject He...
# 1      From waldo cybernet cse fau edu Todd J Dicker ...
# 2      From C L Gannon newcastle ac uk Space Cadet Su...
# 3      From shaig Think COM Shai Guday Subject Basil ...
# 4      From eznumbers hamlet ucdavis edu Subject Re T...
# ...                                                  ...
# 18751  From porta wam umd edu David Palmer Subject Re...
# 18752  From decay cbnewsj cb att com dean kaflowitz S...
# 18753  From ekr kyle eitech com Eric Rescorla Subject...
# 18754  From David R Sacco dsav andrew cmu edu Subject...
# 18755  Subject Re Imaginary Friends Info and Experien...
#
#                        label  \
# 0      talk.politics.mideast
# 1      talk.politics.mideast
# 2      talk.politics.mideast
# 3      talk.politics.mideast
# 4      talk.politics.mideast
# ...                      ...
# 18751     talk.religion.misc
# 18752     talk.religion.misc
# 18753     talk.religion.misc
# 18754     talk.religion.misc
# 18755     talk.religion.misc
#
#                                               clean_data  length  label_idx
# 0      From hm cs brown edu Harry Mamaysky Subject He...     948         17
# 1      From waldo cybernet cse fau edu Todd J Dicker ...     776         17
# 2      From C L Gannon newcastle ac uk Space Cadet Su...     508         17
# 3      From shaig Think COM Shai Guday Subject Basil ...    1289         17
# 4      From eznumbers hamlet ucdavis edu Subject Re T...     862         17
# ...                                                  ...     ...        ...
# 18751  From porta wam umd edu David Palmer Subject Re...     774         19
# 18752  From decay cbnewsj cb att com dean kaflowitz S...     981         19
# 18753  From ekr kyle eitech com Eric Rescorla Subject...    1200         19
# 18754  From David R Sacco dsav andrew cmu edu Subject...     411         19
# 18755  Subject Re Imaginary Friends Info Experiences ...     679         19
#
# [18756 rows x 5 columns]

# %%
X = df.clean_data
y = df.label_idx

X.shape, y.shape
# Out:
# ((18756,), (18756,))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1511)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((15004,), (3752,), (15004,), (3752,))

# %%
tfidf_vectorizer = TfidfVectorizer()
tfidf_vectorizer
# Out:
# TfidfVectorizer()

# %%
naive_bayes_model = MultinomialNB()
naive_bayes_model
# Out:
# MultinomialNB()

# %%
model_pipeline = Pipeline([('vectorizer', tfidf_vectorizer), ('classifier', naive_bayes_model)])
model_pipeline
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                 ('classifier', MultinomialNB())])

# %%
model_pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('vectorizer', TfidfVectorizer()),
#                 ('classifier', MultinomialNB())])

# %%
y_pred = model_pipeline.predict(X_test)
y_pred
# Out:
# array([ 1,  5, 10, ..., 10,  5, 13])

# %%
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.88      0.89       157
#            1       0.78      0.85      0.82       177
#            2       0.87      0.84      0.86       200
#            3       0.89      0.76      0.82       231
#            4       0.85      0.94      0.89       175
#            5       0.85      0.95      0.90       168
#            6       0.80      0.94      0.86       180
#            7       0.91      0.93      0.92       202
#            8       0.98      0.90      0.94       199
#            9       0.98      0.98      0.98       219
#           10       0.98      0.96      0.97       231
#           11       0.98      0.84      0.91       214
#           12       0.81      0.87      0.84       175
#           13       0.94      0.96      0.95       162
#           14       0.96      0.92      0.94       215
#           15       1.00      0.76      0.86       299
#           16       0.98      0.80      0.88       212
#           17       0.99      0.96      0.97       190
#           18       0.76      0.95      0.85       111
#           19       0.28      1.00      0.44        35
#
#     accuracy                           0.89      3752
#    macro avg       0.87      0.90      0.87      3752
# weighted avg       0.91      0.89      0.89      3752
